# %%
import openparticle as op
import numpy as np

# %%
H = op.ParticleOperator('b0^ b0')

max_modes = 1

for i in range(max_modes + 1):
    for j in range(max_modes + 1):
        if i == j == 0:
            coeff = 0
        else: coeff = 1

        H += coeff * op.ParticleOperator('b' + str(i) + '^ ' + 'b' + str(j))

H.display()
# Out:
# $1.0*b^†_0b_0 + 1.0*b^†_0b_1 + 1.0*b^†_1b_0 + 1.0*b^†_1b_1$

# %%
def generate_all_combos_of_fermionic_fock_states(N):
    all_states = []
    for i in range(2**N):
        binary_string = [int(j) for j in format(i, f'0{N}b')]
        f_occ = list(np.nonzero(binary_string)[0])
        all_states.append(op.Fock(f_occ, [], []))

    return all_states

# %%
def generate_matrix_from_basis(operator, basis):

    size = (len(basis), len(basis))
    matrix = np.zeros(size)

    for i, state_i in enumerate(basis):
        for j, state_j in enumerate(basis):
            print(state_i.dagger() * operator * state_j)

# %%
states = generate_all_combos_of_fermionic_fock_states(2)

# %%
states[1].display(), H.display()
# Out:
# $1.0 * |1; ; ⟩$
# $1.0*b^†_0b_0 + 1.0*b^†_0b_1 + 1.0*b^†_1b_0 + 1.0*b^†_1b_1$
# (None, None)

# %%
s =

# %%
(states[1].dagger() * H ).display()
# Out:
# $1.0 * ⟨0; ; | + 1.0 * ⟨1; ; |$

# %%
states[1].dagger().display()
# Out:
# $1.0 * ⟨1; ; |$

# %%
generate_matrix_from_basis(H, states)
# Out:
# 0
# 0
# 0
# 0
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
